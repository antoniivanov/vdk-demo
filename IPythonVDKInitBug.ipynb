# %% [markdown]
# <a href="https://colab.research.google.com/github/antoniivanov/vdk-demo/blob/main/IPythonVDKInitBug.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install quickstart-vdk vdk-notebook vdk-ipython
# Out:
# Collecting quickstart-vdk
#   Downloading quickstart-vdk-0.2.944393829.tar.gz (1.7 kB)
#   Preparing metadata (setup.py) ... done
# Collecting vdk-notebook
#   Downloading vdk-notebook-0.1.1049090626.tar.gz (6.9 kB)
#   Preparing metadata (setup.py) ... done
# Collecting vdk-ipython
#   Downloading vdk-ipython-0.1.989008993.tar.gz (9.8 kB)
#   Preparing metadata (setup.py) ... done
# Collecting vdk-core (from quickstart-vdk)
#   Downloading vdk-core-0.3.1054987393.tar.gz (113 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.1/113.1 kB 1.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting vdk-plugin-control-cli (from quickstart-vdk)
#   Downloading vdk-plugin-control-cli-0.1.948436673.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Collecting vdk-sqlite (from quickstart-vdk)
#   Downloading vdk-sqlite-0.1.954571638.tar.gz (7.1 kB)
#   Preparing metadata (setup.py) ... done
# Collecting vdk-ingest-http (from quickstart-vdk)
#   Downloading vdk-ingest-http-0.2.948436673.tar.gz (7.4 kB)
#   Preparing metadata (setup.py) ... done
# Collecting vdk-ingest-file (from quickstart-vdk)
#   Downloading vdk-ingest-file-0.1.948436673.tar.gz (3.4 kB)
#   Preparing metadata (setup.py) ... done
# Collecting vdk-server (from quickstart-vdk)
#   Downloading vdk-server-0.1.948436673.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Collecting vdk-logging-format (from quickstart-vdk)
#   Downloading vdk-logging-format-0.1.948436673.tar.gz (4.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: iPython in /usr/local/lib/python3.10/dist-packages (from vdk-ipython) (7.34.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from vdk-ipython) (1.5.3)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from iPython->vdk-ipython) (67.7.2)
# Collecting jedi>=0.16 (from iPython->vdk-ipython)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 43.4 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from iPython->vdk-ipython) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from iPython->vdk-ipython) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from iPython->vdk-ipython) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from iPython->vdk-ipython) (3.0.39)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from iPython->vdk-ipython) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from iPython->vdk-ipython) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from iPython->vdk-ipython) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from iPython->vdk-ipython) (4.8.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vdk-ipython) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vdk-ipython) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->vdk-ipython) (1.23.5)
# Requirement already satisfied: click==8.* in /usr/local/lib/python3.10/dist-packages (from vdk-core->quickstart-vdk) (8.1.7)
# Requirement already satisfied: pluggy in /usr/local/lib/python3.10/dist-packages (from vdk-core->quickstart-vdk) (1.3.0)
# Collecting click_log (from vdk-core->quickstart-vdk)
#   Downloading click_log-0.4.0-py2.py3-none-any.whl (4.3 kB)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from vdk-core->quickstart-vdk) (1.1.1)
# Requirement already satisfied: tenacity in /usr/local/lib/python3.10/dist-packages (from vdk-core->quickstart-vdk) (8.2.3)
# Collecting simplejson (from vdk-ingest-http->quickstart-vdk)
#   Downloading simplejson-3.19.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 18.3 MB/s eta 0:00:00
# Collecting ecs-logging (from vdk-logging-format->quickstart-vdk)
#   Downloading ecs_logging-2.1.0-py3-none-any.whl (10 kB)
# Collecting vdk-control-cli (from vdk-plugin-control-cli->quickstart-vdk)
#   Downloading vdk-control-cli-1.3.1020121059.tar.gz (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 6.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vdk-plugin-control-cli->quickstart-vdk) (2.31.0)
# Collecting click-spinner (from vdk-server->quickstart-vdk)
#   Downloading click_spinner-0.1.10-py2.py3-none-any.whl (4.0 kB)
# Collecting docker (from vdk-server->quickstart-vdk)
#   Downloading docker-6.1.3-py3-none-any.whl (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.1/148.1 kB 21.5 MB/s eta 0:00:00
# Collecting kubernetes (from vdk-server->quickstart-vdk)
#   Downloading kubernetes-28.1.0-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 74.2 MB/s eta 0:00:00
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from vdk-sqlite->quickstart-vdk) (0.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->iPython->vdk-ipython) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->iPython->vdk-ipython) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->iPython->vdk-ipython) (0.2.8)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->vdk-ipython) (1.16.0)
# Requirement already satisfied: packaging>=14.0 in /usr/local/lib/python3.10/dist-packages (from docker->vdk-server->quickstart-vdk) (23.2)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from docker->vdk-server->quickstart-vdk) (2.0.7)
# Requirement already satisfied: websocket-client>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from docker->vdk-server->quickstart-vdk) (1.6.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vdk-plugin-control-cli->quickstart-vdk) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vdk-plugin-control-cli->quickstart-vdk) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vdk-plugin-control-cli->quickstart-vdk) (2023.7.22)
# Requirement already satisfied: pyyaml>=5.4.1 in /usr/local/lib/python3.10/dist-packages (from kubernetes->vdk-server->quickstart-vdk) (6.0.1)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from kubernetes->vdk-server->quickstart-vdk) (2.17.3)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.10/dist-packages (from kubernetes->vdk-server->quickstart-vdk) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes->vdk-server->quickstart-vdk) (3.2.2)
# Collecting urllib3>=1.26.0 (from docker->vdk-server->quickstart-vdk)
#   Downloading urllib3-1.26.18-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 19.2 MB/s eta 0:00:00
# Collecting vdk-control-service-api==1.0.11 (from vdk-control-cli->vdk-plugin-control-cli->quickstart-vdk)
#   Downloading vdk-control-service-api-1.0.11.tar.gz (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.0/49.0 kB 7.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting vdk-control-api-auth (from vdk-control-cli->vdk-plugin-control-cli->quickstart-vdk)
#   Downloading vdk-control-api-auth-0.1.1004516448.tar.gz (16 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pydantic<2,>=1.10.5 in /usr/local/lib/python3.10/dist-packages (from vdk-control-service-api==1.0.11->vdk-control-cli->vdk-plugin-control-cli->quickstart-vdk) (1.10.13)
# Collecting aenum (from vdk-control-service-api==1.0.11->vdk-control-cli->vdk-plugin-control-cli->quickstart-vdk)
#   Downloading aenum-3.1.15-py3-none-any.whl (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.6/137.6 kB 21.7 MB/s eta 0:00:00
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes->vdk-server->quickstart-vdk) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes->vdk-server->quickstart-vdk) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes->vdk-server->quickstart-vdk) (4.9)
# Requirement already satisfied: PyJWT in /usr/lib/python3/dist-packages (from vdk-control-api-auth->vdk-control-cli->vdk-plugin-control-cli->quickstart-vdk) (2.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes->vdk-server->quickstart-vdk) (0.5.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<2,>=1.10.5->vdk-control-service-api==1.0.11->vdk-control-cli->vdk-plugin-control-cli->quickstart-vdk) (4.5.0)
# Building wheels for collected packages: quickstart-vdk, vdk-notebook, vdk-ipython, vdk-core, vdk-ingest-file, vdk-ingest-http, vdk-logging-format, vdk-plugin-control-cli, vdk-server, vdk-sqlite, vdk-control-cli, vdk-control-service-api, vdk-control-api-auth
#   Building wheel for quickstart-vdk (setup.py) ... done
#   Created wheel for quickstart-vdk: filename=quickstart_vdk-0.2.944393829-py3-none-any.whl size=1543 sha256=231f32dd8672e59b396d36a62e173752c0a51c7ab071a47fe0aedf45dd1c5005
#   Stored in directory: /root/.cache/pip/wheels/b2/be/d8/004a0d1c970f10288f1997582d0559c9266f365f16dcd296fe
#   Building wheel for vdk-notebook (setup.py) ... done
#   Created wheel for vdk-notebook: filename=vdk_notebook-0.1.1049090626-py3-none-any.whl size=7119 sha256=70c9d377df3e801d8db72784e8c5fdb3894b461e35a7a00a53cd3e2425463646
#   Stored in directory: /root/.cache/pip/wheels/5c/0f/8c/c2289f93e41edc5b08d0462f8bcfd480f414ba42bad1b05a40
#   Building wheel for vdk-ipython (setup.py) ... done
#   Created wheel for vdk-ipython: filename=vdk_ipython-0.1.989008993-py3-none-any.whl size=6935 sha256=8075d9005483527f3accfb170696a892aa408da60eeafce73dbcd49da387c99d
#   Stored in directory: /root/.cache/pip/wheels/17/cf/6f/bb3d057468bfdc8224192600ddf8fc84bb8c70b0446f154bd3
#   Building wheel for vdk-core (setup.py) ... done
#   Created wheel for vdk-core: filename=vdk_core-0.3.1054987393-py2.py3-none-any.whl size=157337 sha256=6642bd3c91481b4c9dc56f1b8fb72cd8c6b855139d4b7f0bc437d0cc2445a35c
#   Stored in directory: /root/.cache/pip/wheels/9e/00/02/2f1ae2c9afa4b85078f6603ebe44cc8a3b8368b73d95ad4584
#   Building wheel for vdk-ingest-file (setup.py) ... done
#   Created wheel for vdk-ingest-file: filename=vdk_ingest_file-0.1.948436673-py3-none-any.whl size=3778 sha256=552104290e40d981931dcea66856da0fc189decb4bd175116ed32311fbff8477
#   Stored in directory: /root/.cache/pip/wheels/ed/5b/4d/5b1bc5f4851aa76e7badb9bbb8d35242704144bc34d759d613
#   Building wheel for vdk-ingest-http (setup.py) ... done
#   Created wheel for vdk-ingest-http: filename=vdk_ingest_http-0.2.948436673-py3-none-any.whl size=6298 sha256=123981c139351ad1fee9ed830656852d3dda2028e3074a169b207a77e23a5462
#   Stored in directory: /root/.cache/pip/wheels/9e/8b/ae/c1e3b1c5088b6b57deb2da989f7aae70949fb47260e82b6c75
#   Building wheel for vdk-logging-format (setup.py) ... done
#   Created wheel for vdk-logging-format: filename=vdk_logging_format-0.1.948436673-py3-none-any.whl size=4715 sha256=21826121b823706ce48fddc89415b0891efd116db51c4f1a4182027b7e9847fc
#   Stored in directory: /root/.cache/pip/wheels/af/b4/aa/8fb19c79fbf61ff495e06aefd2431ff0ad94be1ccb7c5f3f36
#   Building wheel for vdk-plugin-control-cli (setup.py) ... done
#   Created wheel for vdk-plugin-control-cli: filename=vdk_plugin_control_cli-0.1.948436673-py3-none-any.whl size=12620 sha256=1e93db113f44ea44b7b1257077961073ffd87871b2b9b92a84e9247e1d2466bf
#   Stored in directory: /root/.cache/pip/wheels/c8/53/a8/81ea754093f72df77c7b03b9efe44ccdc2805193a3a8765fe0
#   Building wheel for vdk-server (setup.py) ... done
#   Created wheel for vdk-server: filename=vdk_server-0.1.948436673-py3-none-any.whl size=14534 sha256=c8146697299d804c870ee0f8870ed74045139e3394fee84e4ccd1541694dbb6b
#   Stored in directory: /root/.cache/pip/wheels/64/31/da/c4a8a4b8bc10ded92d2f6c2290d789f278bdb9ad5c15dd6a73
#   Building wheel for vdk-sqlite (setup.py) ... done
#   Created wheel for vdk-sqlite: filename=vdk_sqlite-0.1.954571638-py3-none-any.whl size=7043 sha256=d064c003f9ef4a3e226fdc7fd1c065cca3a4a30465d3bfdbea831ec939a7b7ad
#   Stored in directory: /root/.cache/pip/wheels/9b/5e/05/26a18c440e7275ba27f7cc797577ca26a391ff1266c93350ad
#   Building wheel for vdk-control-cli (setup.py) ... done
#   Created wheel for vdk-control-cli: filename=vdk_control_cli-1.3.1020121059-py2.py3-none-any.whl size=64517 sha256=824f0110aec9116754e761a5b5639bbaad4f186584e56c4e28261fefa42afafc
#   Stored in directory: /root/.cache/pip/wheels/08/66/d3/23141a2c96566d9754b2d669624c495d1420f8d28a68ab2c3f
#   Building wheel for vdk-control-service-api (pyproject.toml) ... done
#   Created wheel for vdk-control-service-api: filename=vdk_control_service_api-1.0.11-py3-none-any.whl size=102342 sha256=58a31c7110c09fcc48ac7b66187e34ffcce80e7a6eb6a92a09c6b50ba27cebe3
#   Stored in directory: /root/.cache/pip/wheels/ef/67/0a/554ae32877b9be3b832f77ad6cb2f72abdc44f31ca9468375f
#   Building wheel for vdk-control-api-auth (setup.py) ... done
#   Created wheel for vdk-control-api-auth: filename=vdk_control_api_auth-0.1.1004516448-py3-none-any.whl size=16385 sha256=bc941589b252fa43ae4abcb1fbd6a62cf5a6eb01d91fc061b4dd1cd47d2ca9f0
#   Stored in directory: /root/.cache/pip/wheels/dd/b2/91/03a3c19eef501fad13fa5d82e1c7607891131399ddd2bb8eb6
# Successfully built quickstart-vdk vdk-notebook vdk-ipython vdk-core vdk-ingest-file vdk-ingest-http vdk-logging-format vdk-plugin-control-cli vdk-server vdk-sqlite vdk-control-cli vdk-control-service-api vdk-control-api-auth
# Installing collected packages: click-spinner, aenum, urllib3, simplejson, jedi, ecs-logging, click_log, vdk-core, vdk-control-service-api, vdk-sqlite, vdk-notebook, vdk-logging-format, vdk-ipython, vdk-ingest-http, vdk-ingest-file, docker, vdk-control-api-auth, kubernetes, vdk-server, vdk-control-cli, vdk-plugin-control-cli, quickstart-vdk
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
# Successfully installed aenum-3.1.15 click-spinner-0.1.10 click_log-0.4.0 docker-6.1.3 ecs-logging-2.1.0 jedi-0.19.1 kubernetes-28.1.0 quickstart-vdk-0.2.944393829 simplejson-3.19.2 urllib3-1.26.18 vdk-control-api-auth-0.1.1004516448 vdk-control-cli-1.3.1020121059 vdk-control-service-api-1.0.11 vdk-core-0.3.1054987393 vdk-ingest-file-0.1.948436673 vdk-ingest-http-0.2.948436673 vdk-ipython-0.1.989008993 vdk-logging-format-0.1.948436673 vdk-notebook-0.1.1049090626 vdk-plugin-control-cli-0.1.948436673 vdk-server-0.1.948436673 vdk-sqlite-0.1.954571638

# %%
# %load_ext vdk.plugin.ipython

# %%
# %reload_VDK

# %%
job_input = VDK.get_initialized_job_input()
# Out:
# WARNING:vdk.internal.plugin.plugin:Cannot load plugin from setuptools entrypoint for group vdk.plugin.run
# See exception for possible reason
# The CLI tool will likely abort.
# Re-try again. Check exception message and possibly uninstall a bad plugin (pip uninstall) Or see what plugins are installed (use `pip list` command) and if there aren't issues. Or try to reinstall the app in a new clean environment. Try to revert to previous version of the CLI tool. If nothing works open a SRE ticket.
# ERROR:vdk.internal.plugin.plugin:[Errno 2] No such file or directory: '/usr/local/lib/python3.10/dist-packages/urllib3-2.0.7.dist-info/METADATA'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py", line 3108, in _dep_map
#     return self.__dep_map
#   File "/usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py", line 2901, in __getattr__
#     raise AttributeError(attr)
# AttributeError: _DistInfoDistribution__dep_map
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py", line 3099, in _parsed_pkg_info
#     return self._pkg_info
#   File "/usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py", line 2901, in __getattr__
#     raise AttributeError(attr)
# AttributeError: _pkg_info
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/vdk/internal/plugin/plugin.py", line 56, in load_plugins_from_setuptools_entrypoints
#     self.__plugin_manager.load_setuptools_entrypoints(self.__group_name)
#   File "/usr/local/lib/python3.10/dist-packages/pluggy/_manager.py", line 398, in load_setuptools_entrypoints
#     plugin = ep.load()
#   File "/usr/lib/python3.10/importlib/metadata/__init__.py", line 171, in load
#     module = import_module(match.group('module'))
#   File "/usr/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.10/dist-packages/vdk/plugin/control_cli_plugin/properties_plugin.py", line 10, in <module>
#     from vdk.plugin.control_cli_plugin.control_service_properties_client import (
#   File "/usr/local/lib/python3.10/dist-packages/vdk/plugin/control_cli_plugin/control_service_properties_client.py", line 7, in <module>
#     from vdk.internal.control.rest_lib.factory import ApiClientFactory
#   File "/usr/local/lib/python3.10/dist-packages/vdk/internal/control/rest_lib/factory.py", line 15, in <module>
#     from vdk.internal.control.configuration.vdk_config import VDKConfig
#   File "/usr/local/lib/python3.10/dist-packages/vdk/internal/control/configuration/vdk_config.py", line 12, in <module>
#     from vdk.internal.control.utils import version_utils
#   File "/usr/local/lib/python3.10/dist-packages/vdk/internal/control/utils/version_utils.py", line 10, in <module>
#     __version__ = get_distribution(dist_name).version
#   File "/usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py", line 526, in get_distribution
#     dist = get_provider(dist)
#   File "/usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py", line 398, in get_provider
#     return working_set.find(moduleOrReq) or require(str(moduleOrReq))[0]
#   File "/usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py", line 966, in require
#     needed = self.resolve(parse_requirements(requirements))
#   File "/usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py", line 832, in resolve
#     new_requirements = dist.requires(req.extras)[::-1]
#   File "/usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py", line 2821, in requires
#     dm = self._dep_map
#   File "/usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py", line 3110, in _dep_map
#     self.__dep_map = self._compute_dependencies()
#   File "/usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py", line 3119, in _compute_dependencies
#     for req in self._parsed_pkg_info.get_all('Requires-Dist') or []:
#   File "/usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py", line 3101, in _parsed_pkg_info
#     metadata = self.get_metadata(self.PKG_INFO)
#   File "/usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py", line 1517, in get_metadata
#     value = self._get(path)
#   File "/usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py", line 1726, in _get
#     with open(path, 'rb') as stream:
# FileNotFoundError: [Errno 2] No such file or directory: '/usr/local/lib/python3.10/dist-packages/urllib3-2.0.7.dist-info/METADATA'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py in _dep_map(self)
#    3107         try:
# -> 3108             return self.__dep_map
#    3109         except AttributeError:
#
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py in __getattr__(self, attr)
#    2900         if attr.startswith('_'):
# -> 2901             raise AttributeError(attr)
#    2902         return getattr(self._provider, attr)
#
# AttributeError: _DistInfoDistribution__dep_map
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py in _parsed_pkg_info(self)
#    3098         try:
# -> 3099             return self._pkg_info
#    3100         except AttributeError:
#
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py in __getattr__(self, attr)
#    2900         if attr.startswith('_'):
# -> 2901             raise AttributeError(attr)
#    2902         return getattr(self._provider, attr)
#
# AttributeError: _pkg_info
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/vdk/internal/plugin/plugin.py in load_plugins_from_setuptools_entrypoints(self)
#      55         try:
# ---> 56             self.__plugin_manager.load_setuptools_entrypoints(self.__group_name)
#      57         except ImportError as e:
#
# /usr/local/lib/python3.10/dist-packages/pluggy/_manager.py in load_setuptools_entrypoints(self, group, name)
#     397                     continue
# --> 398                 plugin = ep.load()
#     399                 self.register(plugin, name=ep.name)
#
# /usr/lib/python3.10/importlib/metadata/__init__.py in load(self)
#     170         match = self.pattern.match(self.value)
# --> 171         module = import_module(match.group('module'))
#     172         attrs = filter(None, (match.group('attr') or '').split('.'))
#
# /usr/lib/python3.10/importlib/__init__.py in import_module(name, package)
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/lib/python3.10/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# /usr/local/lib/python3.10/dist-packages/vdk/plugin/control_cli_plugin/properties_plugin.py in <module>
#       9 )
# ---> 10 from vdk.plugin.control_cli_plugin.control_service_properties_client import (
#      11     ControlServicePropertiesServiceClient,
#
# /usr/local/lib/python3.10/dist-packages/vdk/plugin/control_cli_plugin/control_service_properties_client.py in <module>
#       6 from vdk.api.plugin.plugin_input import IPropertiesServiceClient
# ----> 7 from vdk.internal.control.rest_lib.factory import ApiClientFactory
#       8 from vdk.internal.control.rest_lib.rest_client_errors import ApiClientErrorDecorator
#
# /usr/local/lib/python3.10/dist-packages/vdk/internal/control/rest_lib/factory.py in <module>
#      14 from urllib3 import Retry
# ---> 15 from vdk.internal.control.configuration.vdk_config import VDKConfig
#      16 from vdk.plugin.control_api_auth.authentication import Authentication
#
# /usr/local/lib/python3.10/dist-packages/vdk/internal/control/configuration/vdk_config.py in <module>
#      11 from vdk.internal.control.exception.vdk_exception import VDKException
# ---> 12 from vdk.internal.control.utils import version_utils
#      13 from vdk.internal.control.utils.control_utils import read_config_ini_file
#
# /usr/local/lib/python3.10/dist-packages/vdk/internal/control/utils/version_utils.py in <module>
#       9     dist_name = "vdk-control-cli"
# ---> 10     __version__ = get_distribution(dist_name).version
#      11 except DistributionNotFound:  # pragma: no cover
#
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py in get_distribution(dist)
#     525     if isinstance(dist, Requirement):
# --> 526         dist = get_provider(dist)
#     527     if not isinstance(dist, Distribution):
#
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py in get_provider(moduleOrReq)
#     397     if isinstance(moduleOrReq, Requirement):
# --> 398         return working_set.find(moduleOrReq) or require(str(moduleOrReq))[0]
#     399     try:
#
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py in require(self, *requirements)
#     965         """
# --> 966         needed = self.resolve(parse_requirements(requirements))
#     967
#
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py in resolve(self, requirements, env, installer, replace_conflicting, extras)
#     831             # push the new requirements onto the stack
# --> 832             new_requirements = dist.requires(req.extras)[::-1]
#     833             requirements.extend(new_requirements)
#
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py in requires(self, extras)
#    2820         """List of Requirements needed for this distro if `extras` are used"""
# -> 2821         dm = self._dep_map
#    2822         deps = []
#
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py in _dep_map(self)
#    3109         except AttributeError:
# -> 3110             self.__dep_map = self._compute_dependencies()
#    3111             return self.__dep_map
#
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py in _compute_dependencies(self)
#    3118         # Including any condition expressions
# -> 3119         for req in self._parsed_pkg_info.get_all('Requires-Dist') or []:
#    3120             reqs.extend(parse_requirements(req))
#
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py in _parsed_pkg_info(self)
#    3100         except AttributeError:
# -> 3101             metadata = self.get_metadata(self.PKG_INFO)
#    3102             self._pkg_info = email.parser.Parser().parsestr(metadata)
#
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py in get_metadata(self, name)
#    1516         path = self._get_metadata_path(name)
# -> 1517         value = self._get(path)
#    1518         try:
#
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py in _get(self, path)
#    1725     def _get(self, path):
# -> 1726         with open(path, 'rb') as stream:
#    1727             return stream.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/usr/local/lib/python3.10/dist-packages/urllib3-2.0.7.dist-info/METADATA'
#
# The above exception was the direct cause of the following exception:
#
# PluginException                           Traceback (most recent call last)
# <ipython-input-5-c8a5c77ff145> in <cell line: 1>()
# ----> 1 job_input = VDK.get_initialized_job_input()
#
# /usr/local/lib/python3.10/dist-packages/vdk/plugin/ipython/job.py in get_initialized_job_input(self)
#      58         """
#      59         if not self.job_input:
# ---> 60             self.job = standalone_data_job.StandaloneDataJob(
#      61                 name=self._name,
#      62                 template_name=self._template,
#
# /usr/local/lib/python3.10/dist-packages/vdk/internal/builtin_plugins/run/standalone_data_job.py in __init__(self, data_job_directory, name, job_args, extra_plugins, template_name)
#      84         for plugin in extra_plugins:
#      85             self._plugin_registry.load_plugin_with_hooks_impl(plugin)
# ---> 86         self._plugin_registry.load_plugins_from_setuptools_entrypoints()
#      87         self._plugin_registry.add_hook_specs(CoreHookSpecs)
#      88         self._plugin_registry.load_plugin_with_hooks_impl(
#
# /usr/local/lib/python3.10/dist-packages/vdk/internal/plugin/plugin.py in load_plugins_from_setuptools_entrypoints(self)
#      60         except Exception as e:
#      61             log_plugin_load_fail(ResolvableBy.PLATFORM_ERROR, log, e, self.__group_name)
# ---> 62             raise PluginException from e
#      63
#      64         plugins = self.__plugin_manager.list_name_plugin()
#
# PluginException:
